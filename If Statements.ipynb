# %% [markdown]
# # If Statements

# %%
a=20
b=10
if a>b:
    result=a>b
    print( a,"is greater then",b,result)

# %%
number=15
if number>0:
    result:number>0
    print(number,"is positive number",result)
# Out:
# 15 is positive number True

# %%
# Multiple statments in one block
age=20
if age>=18:
 print("you are Adult")
 print("you can vote")
 print("You have full legal Rights ")
# Out:
# you are Adult
# you can vote
# You have full legal Rights

# %%
print("Enter Your Age")
age=int(input())
if age >=18:
 print("You are elegibale to apply for this position")
# Out:
# Enter Your Age
# 17

# %%
print("Enter your Age")
age=int(input())
if age >=18:
 print("You are elegibale to apply for this position")
# Out:
# Enter Your Age
# 19
# You are elegibale to apply for this position

# %% [markdown]
# # Elif Statements

# %%
print("Enter your age")
age=int(input())
if age>=18:
 print("you are eligible to apply for this porsition")
elif age<18:
 print("You are not eligible for this position")
# Out:
# Enter your age
# 17
# You are not eligible for this position

# %%
print("Enter your age")
age=int(input())
if age>=18:
 print("you are eligible to apply for this porsition")
elif age<18:
 print("You are not eligible for this position")
# Out:
# Enter your age
# 18
# you are eligible to apply for this porsition

# %%
print("Enter your age")
age=int(input())
if age>=18:
 print("you are eligible to apply for this porsition")
elif age<18:
 print("You are not eligible for this position")
# Out:
# Enter your age
# 19
# you are eligible to apply for this porsition

# %% [markdown]
# # If else  Statements

# %%
print("Checking even or odd number")
print("Enter number")
number=int(input())
if number%2==0:
 print(f"The {number} is even number")
elif number%2==1:
 print(f"The {number} is odd number")
else:
 print("please try again")
# Out:
# Checking even or odd number
# Enter number
# 2
# The 2 is even number

# %%
print("Checking even or odd number")
print("Enter number")
number=int(input())
if number%2==0:
 print(f"The {number} is even number")
elif number%2==1:
 print(f"The {number} is odd number")
else:
 print("please try again")
# Out:
# Checking even or odd number
# Enter number
# 3
# The 3 is odd number

# %%
print("Checking even or odd number")
print("Enter number")
number=int(input())
if number%2==0:
 print(f"The {number} is even number")
elif number%2==1:
 print(f"The {number} is odd number")
else:
 print("please try again")
# Out:
# Checking even or odd number
# Enter number
# 0
# The 0 is even number

# %%
p
