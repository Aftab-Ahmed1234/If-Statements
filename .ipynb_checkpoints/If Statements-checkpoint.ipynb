# %%
a=20
b=10
if a>b:
    result=a>b
    print( a,"is greater then",b,result)
# Out:
# 20 is greater then 10 True

# %%
number=15
if number>0:
    result:number>0
    print(number,"is positive number",result)
# Out:
# 15 is positive number True

# %%
# Multiple statments in one block
age=20
if age>=18:
 print("you are Adult")
 print("you can vote")
 print("You have full legal Rights ")
# Out:
# you are Adult
# you can vote
# You have full legal Rights

# %%
print("Enter Your Age")
name=input()
if age >=18:
 print("You can are elegibale to apply for this position")
# Out:
# Enter Your Age
# 17
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 print("Enter Your Age")
#       2 name=input()
# ----> 3 if age >=18:
#       4  print("You can are elegibale to apply for this position")
#
# TypeError: '>=' not supported between instances of 'str' and 'int'
